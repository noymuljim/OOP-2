# %%
print("Assalamuialaikum")
# Out:
# Assalamuialaikum

# %%
q = 5
if (q < 10):
    print("q is smaller than 10")

else:
    print("q is greater than 10")
# Out:
# q is smaller than 10

# %%
# taking integer value
age = 24

# taking float value
weight = 68.8

# taking string value
name = "Jim"
print(name)
print(age)
print(weight)
# Out:
# Jim
# 24
# 68.8

# %%
x = 10
y = 5

add = x + y
print(add)
sub = x - y
print(sub)
mul = x * y
print(mul)
mod = x % y
print(mod)
power = x ** y
print(power)
# Out:
# 15
# 5
# 50
# 0
# 100000

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %%
a = 5

b = a
print(b)

b += a
print(b)

b <<= a
print(b)

b -= a
print(b)

b *= a
print(b)
# Out:
# 5
# 10
# 320
# 315
# 1575

# %%
m = 40
if (m < 10):
    print("m is smaller than 10")
elif(m==40):
  print("m is equal 40")
else:
    print("i is greater than 15")
# Out:
# m is equal 40

# %%
for a in range(0, 10,+2):
    print(a)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# while loop
count = 0
while (count < 10):
    count = count + 1
    print("its while loop")
# Out:
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
# its a while loop
